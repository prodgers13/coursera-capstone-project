# %%
# !conda list
# Out:
# # packages in environment at /opt/conda/envs/Python-3.8-main:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# _pytorch_select           1.0                       cpu_2    open-ce
# _tensorflow_select        1.0                       cpu_2    open-ce
# _xgboost_select           1.0                       cpu_2    open-ce
# abseil-cpp                20200225.2           h2531618_0
# absl-py                   0.10.0                   py38_0
# aiohttp                   3.7.4            py38h27cfd23_1
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               20.1.0           py38h27cfd23_1
# arrow-cpp                 3.0.0           py38h79809ca_13_cpu    open-ce
# astropy                   4.2.1            py38h27cfd23_1
# astunparse                1.6.3                      py_0
# ...

# %%
! pip freeze
# Out:
# absl-py @ file:///tmp/build/80754af9/absl-py_1600297518631/work
# aiohttp @ file:///tmp/build/80754af9/aiohttp_1614360992924/work
# appdirs==1.4.4
# argon2-cffi @ file:///tmp/build/80754af9/argon2-cffi_1613037097816/work
# astropy @ file:///tmp/build/80754af9/astropy_1617745353437/work
# astunparse==1.6.3
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# async-timeout==3.0.1
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autoai-libs==1.12.13
# autovizwidget @ file:///tmp/build/80754af9/autovizwidget_1613246391658/work
# av==8.0.2
# azure-core==1.15.0
# azure-cosmos==4.2.0
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# beautifulsoup4 @ file:///home/linux1/recipes/ci/beautifulsoup4_1610988766420/work
# biopython @ file:///tmp/build/80754af9/biopython_1600351907932/work
# black==19.10b0
# bleach @ file:///tmp/build/80754af9/bleach_1612211392645/work
# blinker==1.4
# ...

# %%
# The code was removed by Watson Studio for sharing.
